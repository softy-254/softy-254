# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier as dtc
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import accuracy_score
from sklearn import tree
import numpy as np


#fetching data
cancer_data=pd.read_csv('cancer.csv')
cancer_data
#splitting the data and removing the output predictions
X=cancer_data.drop(columns=['cancer'])
X
#creating output set
y=cancer_data['cancer']
y
#building the model
model=dtc()

#checking accuracy in each set we have training and testing data
X_training, X_testing,y_training,y_testing=tts(X,y,test_size=0.2)


#trainig the model with the data
model.fit(X_training,y_training)
predictions= model.predict(X_testing)
#what the machine will predict depending on the data used to train
predictions
#checking the accuracy
score=accuracy_score(y_testing,predictions)
score
cancer_data.hist(figsize=(50,30),bins=150)

#virtualizatin

"""tree.export_graphviz(model, 
                     out_file='cancer-checker.dot',
                     feature_names=['age','gender','weight','HBP','Fever'],
                     class_names=sorted(y.unique()),
                     label='all',
                     rounded=True,
                     filled=True)"""
"""-> 226 return plot_backend.hist_frame(
    227     data,
    228     column=column,
    229     by=by,
    230     grid=grid,
    231     xlabelsize=xlabelsize,
    232     xrot=xrot,
    233     ylabelsize=ylabelsize,
    234     yrot=yrot,
    235     ax=ax,
    236     sharex=sharex,
    237     sharey=sharey,
    238     figsize=figsize,
    239     layout=layout,
    240     legend=legend,
    241     bins=bins,"""


score
# Out:
# 0.2857142857142857
